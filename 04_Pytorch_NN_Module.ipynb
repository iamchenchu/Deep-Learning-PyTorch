# %% [markdown]
# ### House Price Prediction Script

# %%
import torch 
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "area" : [2600, 3000, 3200, 3600, 4000],
        "age" : [3, 4, 5, 6, 8],
        "price" : [550000, 565000, 610000, 680000, 725000]
    }
)

print(df.to_string(index=False)) # Display the DataFrame without the index column
# Out:
#  area  age  price
#  2600    3 550000
#  3000    4 565000
#  3200    5 610000
#  3600    6 680000
#  4000    8 725000

# %%
X = torch.tensor(df[["area", "age"]].values, dtype=torch.float32)
Y = torch.tensor(df[["price"]].values, dtype=torch.float32)
print(f"\nX: {X} \n\nY: {Y}")
# Out:
# X: tensor([[2.6000e+03, 3.0000e+00],
#         [3.0000e+03, 4.0000e+00],
#         [3.2000e+03, 5.0000e+00],
#         [3.6000e+03, 6.0000e+00],
#         [4.0000e+03, 8.0000e+00]])
#
# Y: tensor([[550000.],
#         [565000.],
#         [610000.],
#         [680000.],
#         [725000.]])

# %%
# These "required_grad=True" will allow PyTorch to compute gradients with respect to these tensors during backpropagation
W = torch.randn((2, 1), requires_grad=True) # 2 features (area, age) and 1 output (price)
B = torch.randn(1, requires_grad=True) # Bias term
print(f"W: {W}\nB: {B}")
# Out:
# W: tensor([[-0.0526],
#         [-0.6787]], requires_grad=True)
# B: tensor([-0.0279], requires_grad=True)
