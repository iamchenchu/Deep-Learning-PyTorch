# %% [markdown]
# #### Rice Classification

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (1.26.19)
# Requirement already satisfied: bleach in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from bleach->kaggle) (23.2)
# Requirement already satisfied: webencodings in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages (from requests->kaggle) (3.4)

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: /Users/mekalathuruchenchaiah/.kaggle: File exists

# %%
# !ls ~/.kaggle

# %%
mv /path/to/kaggle.json ~/.kaggle/
# Out:
# mv: rename /path/to/kaggle.json to /Users/mekalathuruchenchaiah/.kaggle/kaggle.json: No such file or directory

# %%
# !kaggle datasets list
# Out:
# Traceback (most recent call last):
#   File "/Users/mekalathuruchenchaiah/Desktop/PROGRAMMING/Projects/GPU-pytorch/env/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/Users/mekalathuruchenchaiah/Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/Users/mekalathuruchenchaiah/Desktop/PROGRAMMING/Projects/GPU-pytorch/env/lib/python3.8/site-packages/kaggle/api/kaggle_api_extended.py", line 407, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /Users/mekalathuruchenchaiah/.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
mv "/Users/mekalathuruchenchaiah/Desktop/Programming/PyTorch Practice/kaggle.json" ~/.kaggle/

# %%
# !pip install opendatasets --quiet

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/mssmartypants/rice-type-classification")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/mssmartypants/rice-type-classification
# Downloading rice-type-classification.zip to ./rice-type-classification
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 888k/888k [00:00<00:00, 7.25MB/s]

# %%
# %pip install torchsummary
import torch 
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
if torch.cuda.is_available():
    print(f"CUDA is available. GPU: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    print("MPS (Apple Silicon GPU) is available")
else:
    print("No GPU available, using CPU")

print(f"Current device: {device}")
# Out:
# MPS (Apple Silicon GPU) is available
# Current device: mps

# %%
data_df = pd.read_csv("./rice-type-classification/riceClassification.csv")

# %%
data_df.head()
# Out:
#    id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0   1  4537        92.229316        64.012769      0.719916        4677
# 1   2  2872        74.691881        51.400454      0.725553        3015
# 2   3  3048        76.293164        52.043491      0.731211        3132
# 3   4  3073        77.033628        51.928487      0.738639        3157
# 4   5  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
data_df.dropna(inplace=True) # Drop missing values
data_df
