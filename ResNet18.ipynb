# %% [markdown]
# ##### ResNet18

# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ##### Basic Block Implementation
# The core innovation of Resnet is the residual block that uses skip connections to address the vanishing gradient problem in deep networks

# %%
class BasicBlock(nn.Module):
    pass

# %% [markdown]
# ##### Complete ResNet Implementation

# %%
class ResNet(nn.Module):
    pass
