# %%
import torch

# %%
data = torch.tensor([1, 2, 3, 4, 5, 6, 7, 8, 0, 9])

reshape = data.view(5, 2)

print(reshape)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6],
#         [7, 8],
#         [0, 9]])

# %%
flatten = data.view(-1)
print(flatten)
# Out:
# tensor([1, 2, 3, 4, 5, 6, 7, 8, 0, 9])

# %%
reshape.view(-1)
# Out:
# tensor([1, 2, 3, 4, 5, 6, 7, 8, 0, 9])

# %%
t1 = torch.tensor([[[1, 2],
         [3, 4]],
        [[5, 6],
         [7, 8]]])

# %%
t1
# Out:
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]])

# %%
t1.shape
# Out:
# torch.Size([2, 2, 2])

# %%
t2 = t1.view(-1)

# %%
t2
# Out:
# tensor([1, 2, 3, 4, 5, 6, 7, 8])

# %%
t2.shape
# Out:
# torch.Size([8])
